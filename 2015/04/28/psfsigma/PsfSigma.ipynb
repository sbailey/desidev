# %% [markdown]
# ## Summary ##
#
# This notebook is to study how the PSF varies across the CCD.
# Something is strange with the sigma calculation that leaves
# artifacts.  Work in progress.

# %%
import desimodel.io
import numpy as np

# %%
psf = desimodel.io.load_psf('r')

# %%
nwave = nspec = 500
wavelengths = np.linspace(psf.wmin_all, psf.wmax_all, nwave)
sigx = np.zeros((nspec, nwave))
for i in range(nspec):
    sigx[i] = psf.xsigma(i, wavelengths)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
imshow(sigx - np.median(sigx), vmin=-0.05, vmax=0.05)
set_cmap('RdBu')
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x1100b8b90>

# %%
psf.xsigma()
